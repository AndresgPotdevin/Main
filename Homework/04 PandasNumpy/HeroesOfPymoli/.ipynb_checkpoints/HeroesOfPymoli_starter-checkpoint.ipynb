# %% [markdown]
# ### Heroes Of Pymoli Data Analysis
# * Of the 1163 active players, the vast majority are male (84%). There also exists, a smaller, but notable proportion of female players (14%).
#
# * Our peak age demographic falls between 20-24 (44.8%) with secondary groups falling between 15-19 (18.60%) and 25-29 (13.4%).
# -----

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
purchase_data_csv = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data_df = pd.read_csv(purchase_data_csv)
purchase_data_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
#Count Unique number of total Players
total_players = len(purchase_data_df["SN"].unique())

#Display in DataFrame
player_count_df = pd.DataFrame({"Total Players": [total_players]})
player_count_df
# Out:
#    Total Players
# 0            576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#Purchasing Analysis
number_of_unique_items = len(purchase_data_df["Item ID"].unique())
average_price = purchase_data_df["Price"].mean()
number_of_purchases = len(purchase_data_df["Purchase ID"])
total_revenue = purchase_data_df["Price"].sum()

#Purchase Analysis DataFrame
purchasing_analysis_df = pd.DataFrame({"Number of Unique Items": [number_of_unique_items],
                                      "Average Price": [average_price],
                                      "Numer of Purchases": [number_of_purchases],
                                      "Total Revenue": total_revenue})

#DataFrame Formatting
purchasing_analysis_df["Average Price"] = purchasing_analysis_df["Average Price"].astype(float).map("${:,.2f}".format)
purchasing_analysis_df["Total Revenue"] = purchasing_analysis_df["Total Revenue"].astype(float).map("${:,.2f}".format)
purchasing_analysis_df
# Out:
#    Number of Unique Items Average Price  Numer of Purchases Total Revenue
# 0                     183         $3.05                 780     $2,379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
#Gender Demographic Analysis
male_list = purchase_data_df.loc[purchase_data_df['Gender'] == "Male"]
male_counts = male_list['SN'].nunique()
male_percent = male_counts / total_players * 100
female_list = purchase_data_df.loc[purchase_data_df['Gender'] == "Female"]
female_counts = female_list['SN'].nunique()
female_percent = female_counts / total_players * 100
non_disclosed_list = purchase_data_df.loc[purchase_data_df['Gender'] == "Other / Non-Disclosed"]
non_disclosed_counts = non_disclosed_list['SN'].nunique()
non_disclosed_percent = non_disclosed_counts / total_players * 100

#Gender Demographics DataFrame
gender_demographics_df = pd.DataFrame({"":['Female','Male','Other / Non-Disclosed'],
                                      "Total Count":[female_counts,male_counts,non_disclosed_counts],
                                      "Percentage of Players":[female_percent,male_percent,non_disclosed_percent]})

#DataFrame Formatting
gender_demographics_df['Percentage of Players'] = gender_demographics_df['Percentage of Players'].astype(float).map("{:.2f}%".format)
gender_demographics_df = gender_demographics_df.set_index('')

#Show DataFrame
gender_demographics_df
# Out:
#                        Total Count Percentage of Players
#
# Female                          81                14.06%
# Male                           484                84.03%
# Other / Non-Disclosed           11                 1.91%

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#Group Data by Gender
groupby_gender_df = purchase_data_df.groupby(['Gender'])

#Purchase Analysis by gender
gender_purchase_count = groupby_gender_df["SN"].count()
gender_average_purchase_price = groupby_gender_df["Price"].mean()
gender_total_purchase_value = groupby_gender_df["Price"].sum()
gender_total_purchase_per_person = groupby_gender_df['Price'].sum() / gender_demographics_df["Total Count"]

#Create DataFrame
gender_purchasing_analysis_df = pd.DataFrame({"Purchase Count":gender_purchase_count,
                                             "Average Purchase Price":gender_average_purchase_price,
                                             "Total Purchase Value":gender_total_purchase_value,
                                             "Avg Total Purchase per Person":gender_total_purchase_per_person})

#Format DataFrame
gender_purchasing_analysis_df["Average Purchase Price"] = gender_purchasing_analysis_df["Average Purchase Price"].astype(float).map("${:.2f}".format)
gender_purchasing_analysis_df["Total Purchase Value"] = gender_purchasing_analysis_df["Total Purchase Value"].astype(float).map("${:.2f}".format)
gender_purchasing_analysis_df["Avg Total Purchase per Person"] = gender_purchasing_analysis_df["Avg Total Purchase per Person"].astype(float).map("${:.2f}".format)

#Show DataFrame
gender_purchasing_analysis_df
# Out:
#                        Purchase Count Average Purchase Price  \
# Gender
# Female                            113                  $3.20
# Male                              652                  $3.02
# Other / Non-Disclosed              15                  $3.35
#
#                       Total Purchase Value Avg Total Purchase per Person
# Gender
# Female                             $361.94                         $4.47
# Male                              $1967.64                         $4.07
# Other / Non-Disclosed               $50.19                         $4.56

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
#Create Bins and Labels
bins = [0,9,14,19,24,29,34,39,200]
age_ranges = ["<10","10-14","15-19","20-24","25-29","30-34","35-39","40+"]

#List by unique SN and Age
player_age_list = purchase_data_df.loc[:,["SN","Age"]]
player_age_list = player_age_list.drop_duplicates()

#Sort data into Bins
player_age_list["Age Range"] = pd.cut(player_age_list["Age"], bins, labels=age_ranges)
total_count = player_age_list["Age Range"].value_counts()
percentage_of_players = (total_count / total_players * 100).round(2)

#Create DataFrame
age_demographics_df = pd.DataFrame({"Total Count":total_count,
                                   "Percentage of Players":percentage_of_players})

#Sort by index
age_demographics_df.sort_index()
# Out:
#        Total Count  Percentage of Players
# <10             17                   2.95
# 10-14           22                   3.82
# 15-19          107                  18.58
# 20-24          258                  44.79
# 25-29           77                  13.37
# 30-34           52                   9.03
# 35-39           31                   5.38
# 40+             12                   2.08

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#Bin data into pre-existing Bins
purchase_data_df["Age Ranges"] = pd.cut(purchase_data_df["Age"], bins, labels=age_ranges)

#Purchase Analysis by Age
age_purchase_count = purchase_data_df["Age Ranges"].value_counts()
age_average_price = purchase_data_df.groupby(["Age Ranges"]).mean()["Price"]
age_total_purchase = purchase_data_df.groupby(["Age Ranges"]).sum()["Price"]
age_average_total = (age_total_purchase / total_count)

#Make DataFrame
age_purchase_analysis_df = pd.DataFrame({"Purchase Count":age_purchase_count,
                                        "Average Purchase Price":age_average_price,
                                        "Total Purchase Value":age_total_purchase,
                                        "Avg Total Purchase per Person":age_average_total})

#Format DataFrame
age_purchase_analysis_df['Average Purchase Price']= age_purchase_analysis_df['Average Purchase Price'].map("${:.2f}".format)
age_purchase_analysis_df['Total Purchase Value']= age_purchase_analysis_df['Total Purchase Value'].map("${:.2f}".format)
age_purchase_analysis_df['Avg Total Purchase per Person']= age_purchase_analysis_df['Avg Total Purchase per Person'].map("${:.2f}".format)

#Show DataFrame sorted by index
age_purchase_analysis_df.sort_index()
# Out:
#        Purchase Count Average Purchase Price Total Purchase Value  \
# 10-14              28                  $2.96               $82.78
# 15-19             136                  $3.04              $412.89
# 20-24             365                  $3.05             $1114.06
# 25-29             101                  $2.90              $293.00
# 30-34              73                  $2.93              $214.00
# 35-39              41                  $3.60              $147.67
# 40+                13                  $2.94               $38.24
# <10                23                  $3.35               $77.13
#
#       Avg Total Purchase per Person
# 10-14                         $3.76
# 15-19                         $3.86
# 20-24                         $4.32
# 25-29                         $3.81
# 30-34                         $4.12
# 35-39                         $4.76
# 40+                           $3.19
# <10                           $4.54

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
#Sort by name
sn_list = purchase_data_df.groupby('SN')

#Top Spenders Analysis
sn_purchase_count = sn_list['Item ID'].count()
sn_average_price = sn_list['Price'].mean()
sn_total_purchase = sn_list['Price'].sum()

#Create DataFrame
top_spenders_df = pd.DataFrame({"Purchase Count":sn_purchase_count,
                               "Average Purchase Count":sn_average_price,
                               "Total Purchase Value":sn_total_purchase})

#Format DataFrame
top_spenders_df = top_spenders_df.sort_values(['Total Purchase Value'], ascending=False)
top_spenders_df['Average Purchase Count'] = top_spenders_df['Average Purchase Count'].map("${:.2f}".format)
top_spenders_df['Total Purchase Value'] = top_spenders_df['Total Purchase Value'].map("${:.2f}".format)



top_spenders_df.head()
# Out:
#              Purchase Count Average Purchase Count Total Purchase Value
# SN
# Lisosia93                 5                  $3.79               $18.96
# Idastidru52               4                  $3.86               $15.45
# Chamjask73                3                  $4.61               $13.83
# Iral74                    4                  $3.40               $13.62
# Iskadarya95               3                  $4.37               $13.10

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
#Retrieve ID, Items name and Price
popular_items_df = purchase_data_df[['Item ID','Item Name','Price']]

#Group by ID and Name
popular_items_list = popular_items_df.groupby(['Item ID','Item Name'])

#Popular Items purchase analysis
item_purchase_count = popular_items_list['Item ID'].count()
item_price = item_total_value / item_purchase_count
item_total_value = popular_items_list['Price'].sum()

#Create DataFrame
most_popular_items_df = pd.DataFrame({"Purchase Count":item_purchase_count,
                                     "Item Price":item_price,
                                     "Total Purchase Value":item_total_value})

#Format DataFrame
sorted_most_popular_items_df = most_popular_items_df.sort_values('Purchase Count', ascending=False)
sorted_most_popular_items_df.style.format({'Item Price':"${:,.2f}",'Total Purchase Value':"${:,.2f}"})

#Show DataFrame
sorted_most_popular_items_df.head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 145     Fiery Glass Crusader                                       9
# 108     Extraction, Quickblade Of Trembling Hands                  9
# 82      Nirvana                                                    9
# 19      Pursuit, Cudgel of Necromancy                              8
#
#                                                       Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm        4.23
# 145     Fiery Glass Crusader                                4.58
# 108     Extraction, Quickblade Of Trembling Hands           3.53
# 82      Nirvana                                             4.90
# 19      Pursuit, Cudgel of Necromancy                       1.02
#
#                                                       Total Purchase Value
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm                 50.76
# 145     Fiery Glass Crusader                                         41.22
# 108     Extraction, Quickblade Of Trembling Hands                    31.77
# 82      Nirvana                                                      44.10
# 19      Pursuit, Cudgel of Necromancy                                 8.16

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
sorted_most_profitable_items_df = most_popular_items_df.sort_values('Total Purchase Value', ascending=False)
sorted_most_profitable_items_df.head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 92      Final Critic                                               8
# 103     Singed Scalpel                                             8
#
#                                                       Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm        4.23
# 82      Nirvana                                             4.90
# 145     Fiery Glass Crusader                                4.58
# 92      Final Critic                                        4.88
# 103     Singed Scalpel                                      4.35
#
#                                                       Total Purchase Value
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm                 50.76
# 82      Nirvana                                                      44.10
# 145     Fiery Glass Crusader                                         41.22
# 92      Final Critic                                                 39.04
# 103     Singed Scalpel                                               34.80
